# %% [markdown]
# <a href="https://colab.research.google.com/github/hc2twv/UPSE_OP/blob/main/SistemaDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implementación del Sistema DAS en Python
# Paso 1: Definir los parámetros básicos
# Definiremos los parámetros del sistema, como el tamaño de la cuadrícula, el número de antenas y la población inicial.
#
# Paso 2: Inicializar la población
# Crearemos una población inicial de posibles ubicaciones para las antenas.
#
# Paso 3: Evaluar la cobertura
# Desarrollaremos una función para calcular la cobertura proporcionada por un conjunto de antenas en la cuadrícula.
#
# Paso 4: Selección, Cruzamiento y Mutación
# Implementaremos funciones para la selección de padres, cruzamiento y mutación para generar nuevas soluciones.
#
# Paso 5: Algoritmo Genético
# Implementaremos el algoritmo genético para optimizar la ubicación de las antenas.

# %%
import random
import numpy as np

# Parámetros del DAS
grid_size = 20  # Tamaño de la cuadrícula
num_antennas = 5  # Número de antenas en el DAS
population_size = 30  # Tamaño de la población de soluciones
generations = 200  # Número de generaciones para evolucionar
mutation_rate = 0.05  # Tasa de mutación de las soluciones

# Inicializar una población de posibles ubicaciones de antenas
def initialize_population(pop_size, num_antennas, grid_size):
    # Cada individuo en la población es un conjunto de coordenadas (x, y) para las antenas
    return [np.random.randint(0, grid_size, size=(num_antennas, 2)) for _ in range(pop_size)]

# Calcular la cobertura de una solución (ubicaciones de antenas)
def calculate_coverage(solution, grid_size):
    coverage_grid = np.zeros((grid_size, grid_size))
    for x, y in solution:
        # Considerar que cada antena cubre un área circular con un radio fijo
        for i in range(grid_size):
            for j in range(grid_size):
                if np.sqrt((x - i) ** 2 + (y - j) ** 2) <= 3:  # Radio de cobertura de 3 unidades
                    coverage_grid[i][j] = 1
    return np.sum(coverage_grid)

# Evaluar la aptitud de cada individuo en la población
def evaluate_population(population, grid_size):
    return [calculate_coverage(individual, grid_size) for individual in population]

# Seleccionar padres para el cruce basado en su aptitud
def select_parents(population, fitness):
    # Selección proporcional a la aptitud
    selected = random.choices(population, weights=fitness, k=2)
    return selected

# Cruzar dos padres para generar un hijo
def crossover(parent1, parent2):
    crossover_point = random.randint(0, len(parent1) - 1)
    # El hijo hereda una parte de las coordenadas de cada padre
    child = np.vstack((parent1[:crossover_point], parent2[crossover_point:]))
    return child

# Mutar un hijo introduciendo variabilidad
def mutate(child, mutation_rate, grid_size):
    for i in range(len(child)):
        if random.random() < mutation_rate:
            # Cambiar aleatoriamente la posición de una antena
            child[i] = np.random.randint(0, grid_size, size=2)
    return child

# Algoritmo Genético Principal para optimizar el DAS
def genetic_algorithm(grid_size, num_antennas, pop_size, generations, mutation_rate):
    population = initialize_population(pop_size, num_antennas, grid_size)

    for generation in range(generations):
        fitness = evaluate_population(population, grid_size)
        new_population = []

        for _ in range(pop_size // 2):
            parent1, parent2 = select_parents(population, fitness)
            child1 = mutate(crossover(parent1, parent2), mutation_rate, grid_size)
            child2 = mutate(crossover(parent2, parent1), mutation_rate, grid_size)
            new_population.extend([child1, child2])

        population = new_population

        # Imprimir la mejor solución de cada generación
        best_fitness = max(fitness)
        print(f'Generación {generation + 1}, Mejor Aptitud: {best_fitness}')

    # Retornar la mejor solución encontrada
    best_solution_index = fitness.index(max(fitness))
    return population[best_solution_index]

# Ejecutar el algoritmo genético para optimizar la ubicación de las antenas DAS
best_solution = genetic_algorithm(grid_size, num_antennas, population_size, generations, mutation_rate)
print('Mejor Solución:', best_solution)
# Out:
# Generación 1, Mejor Aptitud: 137.0
# Generación 2, Mejor Aptitud: 137.0
# Generación 3, Mejor Aptitud: 137.0
# Generación 4, Mejor Aptitud: 134.0
# Generación 5, Mejor Aptitud: 142.0
# Generación 6, Mejor Aptitud: 142.0
# Generación 7, Mejor Aptitud: 143.0
# Generación 8, Mejor Aptitud: 143.0
# Generación 9, Mejor Aptitud: 145.0
# Generación 10, Mejor Aptitud: 136.0
# Generación 11, Mejor Aptitud: 143.0
# Generación 12, Mejor Aptitud: 143.0
# Generación 13, Mejor Aptitud: 136.0
# Generación 14, Mejor Aptitud: 136.0
# Generación 15, Mejor Aptitud: 137.0
# Generación 16, Mejor Aptitud: 140.0
# Generación 17, Mejor Aptitud: 140.0
# Generación 18, Mejor Aptitud: 143.0
# Generación 19, Mejor Aptitud: 144.0
# Generación 20, Mejor Aptitud: 144.0
# Generación 21, Mejor Aptitud: 142.0
# Generación 22, Mejor Aptitud: 140.0
# Generación 23, Mejor Aptitud: 140.0
# Generación 24, Mejor Aptitud: 140.0
# Generación 25, Mejor Aptitud: 139.0
# Generación 26, Mejor Aptitud: 141.0
# Generación 27, Mejor Aptitud: 144.0
# Generación 28, Mejor Aptitud: 139.0
# Generación 29, Mejor Aptitud: 139.0
# Generación 30, Mejor Aptitud: 141.0
# Generación 31, Mejor Aptitud: 144.0
# Generación 32, Mejor Aptitud: 139.0
# Generación 33, Mejor Aptitud: 137.0
# Generación 34, Mejor Aptitud: 139.0
# Generación 35, Mejor Aptitud: 143.0
# Generación 36, Mejor Aptitud: 143.0
# Generación 37, Mejor Aptitud: 139.0
# Generación 38, Mejor Aptitud: 139.0
# Generación 39, Mejor Aptitud: 137.0
# Generación 40, Mejor Aptitud: 137.0
# Generación 41, Mejor Aptitud: 137.0
# Generación 42, Mejor Aptitud: 137.0
# Generación 43, Mejor Aptitud: 137.0
# Generación 44, Mejor Aptitud: 136.0
# Generación 45, Mejor Aptitud: 137.0
# Generación 46, Mejor Aptitud: 137.0
# Generación 47, Mejor Aptitud: 136.0
# Generación 48, Mejor Aptitud: 136.0
# Generación 49, Mejor Aptitud: 131.0
# Generación 50, Mejor Aptitud: 135.0
# Generación 51, Mejor Aptitud: 137.0
# Generación 52, Mejor Aptitud: 135.0
# Generación 53, Mejor Aptitud: 135.0
# Generación 54, Mejor Aptitud: 139.0
# Generación 55, Mejor Aptitud: 133.0
# Generación 56, Mejor Aptitud: 137.0
# Generación 57, Mejor Aptitud: 139.0
# Generación 58, Mejor Aptitud: 142.0
# Generación 59, Mejor Aptitud: 140.0
# Generación 60, Mejor Aptitud: 138.0
# Generación 61, Mejor Aptitud: 138.0
# Generación 62, Mejor Aptitud: 136.0
# Generación 63, Mejor Aptitud: 137.0
# Generación 64, Mejor Aptitud: 135.0
# Generación 65, Mejor Aptitud: 141.0
# Generación 66, Mejor Aptitud: 137.0
# Generación 67, Mejor Aptitud: 139.0
# Generación 68, Mejor Aptitud: 138.0
# Generación 69, Mejor Aptitud: 138.0
# Generación 70, Mejor Aptitud: 144.0
# Generación 71, Mejor Aptitud: 142.0
# Generación 72, Mejor Aptitud: 134.0
# Generación 73, Mejor Aptitud: 142.0
# Generación 74, Mejor Aptitud: 136.0
# Generación 75, Mejor Aptitud: 140.0
# Generación 76, Mejor Aptitud: 142.0
# Generación 77, Mejor Aptitud: 141.0
# Generación 78, Mejor Aptitud: 141.0
# Generación 79, Mejor Aptitud: 140.0
# Generación 80, Mejor Aptitud: 144.0
# Generación 81, Mejor Aptitud: 138.0
# Generación 82, Mejor Aptitud: 138.0
# Generación 83, Mejor Aptitud: 142.0
# Generación 84, Mejor Aptitud: 142.0
# Generación 85, Mejor Aptitud: 142.0
# Generación 86, Mejor Aptitud: 141.0
# Generación 87, Mejor Aptitud: 144.0
# Generación 88, Mejor Aptitud: 138.0
# Generación 89, Mejor Aptitud: 139.0
# Generación 90, Mejor Aptitud: 144.0
# Generación 91, Mejor Aptitud: 144.0
# Generación 92, Mejor Aptitud: 144.0
# Generación 93, Mejor Aptitud: 143.0
# Generación 94, Mejor Aptitud: 141.0
# Generación 95, Mejor Aptitud: 142.0
# Generación 96, Mejor Aptitud: 140.0
# Generación 97, Mejor Aptitud: 140.0
# Generación 98, Mejor Aptitud: 143.0
# Generación 99, Mejor Aptitud: 138.0
# Generación 100, Mejor Aptitud: 137.0
# Generación 101, Mejor Aptitud: 136.0
# Generación 102, Mejor Aptitud: 137.0
# Generación 103, Mejor Aptitud: 133.0
# Generación 104, Mejor Aptitud: 133.0
# Generación 105, Mejor Aptitud: 137.0
# Generación 106, Mejor Aptitud: 138.0
# Generación 107, Mejor Aptitud: 131.0
# Generación 108, Mejor Aptitud: 136.0
# Generación 109, Mejor Aptitud: 143.0
# Generación 110, Mejor Aptitud: 134.0
# Generación 111, Mejor Aptitud: 131.0
# Generación 112, Mejor Aptitud: 131.0
# Generación 113, Mejor Aptitud: 139.0
# Generación 114, Mejor Aptitud: 139.0
# Generación 115, Mejor Aptitud: 139.0
# Generación 116, Mejor Aptitud: 122.0
# Generación 117, Mejor Aptitud: 136.0
# Generación 118, Mejor Aptitud: 130.0
# Generación 119, Mejor Aptitud: 136.0
# Generación 120, Mejor Aptitud: 136.0
# Generación 121, Mejor Aptitud: 138.0
# Generación 122, Mejor Aptitud: 137.0
# Generación 123, Mejor Aptitud: 140.0
# Generación 124, Mejor Aptitud: 140.0
# Generación 125, Mejor Aptitud: 137.0
# Generación 126, Mejor Aptitud: 141.0
# Generación 127, Mejor Aptitud: 141.0
# Generación 128, Mejor Aptitud: 141.0
# Generación 129, Mejor Aptitud: 139.0
# Generación 130, Mejor Aptitud: 139.0
# Generación 131, Mejor Aptitud: 139.0
# Generación 132, Mejor Aptitud: 139.0
# Generación 133, Mejor Aptitud: 139.0
# Generación 134, Mejor Aptitud: 138.0
# Generación 135, Mejor Aptitud: 139.0
# Generación 136, Mejor Aptitud: 141.0
# Generación 137, Mejor Aptitud: 139.0
# Generación 138, Mejor Aptitud: 138.0
# Generación 139, Mejor Aptitud: 129.0
# Generación 140, Mejor Aptitud: 141.0
# Generación 141, Mejor Aptitud: 141.0
# Generación 142, Mejor Aptitud: 141.0
# Generación 143, Mejor Aptitud: 139.0
# Generación 144, Mejor Aptitud: 141.0
# Generación 145, Mejor Aptitud: 137.0
# Generación 146, Mejor Aptitud: 137.0
# Generación 147, Mejor Aptitud: 138.0
# Generación 148, Mejor Aptitud: 138.0
# Generación 149, Mejor Aptitud: 137.0
# Generación 150, Mejor Aptitud: 137.0
# Generación 151, Mejor Aptitud: 142.0
# Generación 152, Mejor Aptitud: 137.0
# Generación 153, Mejor Aptitud: 142.0
# Generación 154, Mejor Aptitud: 143.0
# Generación 155, Mejor Aptitud: 143.0
# Generación 156, Mejor Aptitud: 137.0
# Generación 157, Mejor Aptitud: 137.0
# Generación 158, Mejor Aptitud: 137.0
# Generación 159, Mejor Aptitud: 131.0
# Generación 160, Mejor Aptitud: 137.0
# Generación 161, Mejor Aptitud: 137.0
# Generación 162, Mejor Aptitud: 137.0
# Generación 163, Mejor Aptitud: 144.0
# Generación 164, Mejor Aptitud: 144.0
# Generación 165, Mejor Aptitud: 144.0
# Generación 166, Mejor Aptitud: 139.0
# Generación 167, Mejor Aptitud: 138.0
# Generación 168, Mejor Aptitud: 139.0
# Generación 169, Mejor Aptitud: 142.0
# Generación 170, Mejor Aptitud: 138.0
# Generación 171, Mejor Aptitud: 142.0
# Generación 172, Mejor Aptitud: 134.0
# Generación 173, Mejor Aptitud: 133.0
# Generación 174, Mejor Aptitud: 139.0
# Generación 175, Mejor Aptitud: 138.0
# Generación 176, Mejor Aptitud: 130.0
# Generación 177, Mejor Aptitud: 134.0
# Generación 178, Mejor Aptitud: 134.0
# Generación 179, Mejor Aptitud: 134.0
# Generación 180, Mejor Aptitud: 131.0
# Generación 181, Mejor Aptitud: 137.0
# Generación 182, Mejor Aptitud: 137.0
# Generación 183, Mejor Aptitud: 138.0
# Generación 184, Mejor Aptitud: 137.0
# Generación 185, Mejor Aptitud: 138.0
# Generación 186, Mejor Aptitud: 138.0
# Generación 187, Mejor Aptitud: 138.0
# Generación 188, Mejor Aptitud: 138.0
# Generación 189, Mejor Aptitud: 138.0
# Generación 190, Mejor Aptitud: 138.0
# Generación 191, Mejor Aptitud: 134.0
# Generación 192, Mejor Aptitud: 132.0
# Generación 193, Mejor Aptitud: 134.0
# Generación 194, Mejor Aptitud: 134.0
# Generación 195, Mejor Aptitud: 137.0
# Generación 196, Mejor Aptitud: 133.0
# Generación 197, Mejor Aptitud: 137.0
# Generación 198, Mejor Aptitud: 138.0
# Generación 199, Mejor Aptitud: 138.0
# Generación 200, Mejor Aptitud: 143.0
# Mejor Solución: [[14 16]
#  [ 8 19]
#  [12 19]
#  [12  5]
#  [ 9  6]]
