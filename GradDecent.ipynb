# %% [markdown]
# <a href="https://colab.research.google.com/github/hc2twv/UPSE_OP/blob/main/GradDecent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El algoritmo de gradiente descendente es utilizado para minimizar funciones continuas y diferenciables. Es muy común en el aprendizaje automático y la optimización de funciones.

# %% [markdown]
# Ejemplo: Usaremos una simple regresión lineal como ejemplo, donde intentamos ajustar una línea recta
# 𝑦
# =
# 𝑚
# 𝑥
# +
# 𝑏
# y=mx+b a un conjunto de datos.

# %% [markdown]
# **Paso 1: Generar Datos de Ejemplo**
#
# Primero, generamos un conjunto de datos sintéticos.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos sintéticos
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

plt.scatter(X, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Datos sintéticos')
plt.show()

# %% [markdown]
# **Paso 2: Implementar el Algoritmo de Gradiente Descendente**
#
# Implementamos el algoritmo de Gradiente Descendente para minimizar la función de costo de la regresión lineal.

# %%
# Inicialización de parámetros
m = 0
b = 0
learning_rate = 0.01
n_iterations = 1000
n = len(X)

# Función de costo
def compute_cost(X, y, m, b):
    y_pred = m * X + b
    cost = (1 / (2 * n)) * np.sum((y_pred - y) ** 2)
    return cost

# Gradiente Descendente
cost_history = []

for i in range(n_iterations):
    y_pred = m * X + b
    dm = (1 / n) * np.sum(X * (y_pred - y))
    db = (1 / n) * np.sum(y_pred - y)

    m -= learning_rate * dm
    b -= learning_rate * db

    cost = compute_cost(X, y, m, b)
    cost_history.append(cost)

    if i % 100 == 0:
        print(f'Iteración {i+1}: m = {m}, b = {b}, Costo = {cost}')

# Parámetros finales
print(f'Parámetros finales: m = {m}, b = {b}')
# Out:
# Iteración 1: m = 0.07384082580524261, b = 0.06820004100101898, Costo = 24.004207929339433
# Iteración 101: m = 3.0661707260513253, b = 2.986174760981785, Costo = 0.8703957618389504
# Iteración 201: m = 3.339006771735625, b = 3.459883274474828, Costo = 0.484258101907274
# Iteración 301: m = 3.2897369493438093, b = 3.6128218257403506, Costo = 0.4570629343886856
# Iteración 401: m = 3.213478949652705, b = 3.7112444751570552, Costo = 0.4415159728089947
# Iteración 501: m = 3.144829028755922, b = 3.790491538274934, Costo = 0.4305056830423417
# Iteración 601: m = 3.086368975016969, b = 3.8568874535516002, Costo = 0.4226675347059108
# Iteración 701: m = 3.0369748914552033, b = 3.9128528779447533, Costo = 0.41708698135230365
# Iteración 801: m = 2.9952886163498773, b = 3.9600684682791214, Costo = 0.41311376593236226
# Iteración 901: m = 2.960113290248754, b = 3.9999074318928995, Costo = 0.41028493506068137
# Parámetros finales: m = 2.9307052510870104, b = 4.033214213676792

# %% [markdown]
# **Paso 3: Visualización de la Convergencia**
#
# Podemos visualizar cómo la función de costo disminuye con el tiempo.

# %%
plt.plot(range(n_iterations), cost_history)
plt.xlabel('Iteraciones')
plt.ylabel('Costo')
plt.title('Convergencia de Gradiente Descendente')
plt.show()

# %% [markdown]
# **Paso 4: Visualización del Ajuste Final**
#
# Finalmente, podemos visualizar cómo la línea ajustada se compara con los datos originales.

# %%
plt.scatter(X, y, label='Datos')
plt.plot(X, m * X + b, color='red', label='Ajuste lineal')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Ajuste lineal usando Gradiente Descendente')
plt.show()
